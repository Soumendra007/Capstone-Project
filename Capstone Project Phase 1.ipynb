# %% [markdown]
# # Capstone Project

# %% [markdown]
# # (Crimes in India)

# %% [markdown]
# **Important notes.**

# %% [markdown]
# *1. By now you have worked on many use cases. As this is a capstone project and absolutely No support will be given from the technical team so avoid asking questions on the capstone project.*
#
# *2. When you are analyzing any situation if you don’t get proper data/information or are in doubt about anything. You are free to make assumptions and proceed. But make sure whenever you assume something you MUST write what is your assumption w.r.t that situation so that we understand your work accordingly.*
#
# *3. You can merge all the files or work on them individually it's up to you how you think and want to deal with it.*
#
# *4. You can make use of any column data for your analysis there is no fixed procedure to follow as long as your analysis makes sense.*
#
# *5. A simple point to keep in mind, the more the analysis is the better.*
#
# *6. For every analysis, document your analysis within the jupyter notebook (in the same cell where your graph or code exists)*
#
# *7. Write Phase number and Req. Numb for every task to identify later. You can combine requirement numbers where it is necessary.*
#
# *8. You need to post your complete work in LMS*
#
# *9. These marks will be considered for your placement-related activities.*
#
# *10. You can use ANY library/module.*

# %% [markdown]
# # Phase 1

# %% [markdown]
# # Data Collection/preparation part.

# %% [markdown]
# **Note:**

# %% [markdown]
# *1. You can collect data from anywhere (wiki, google, etc) but mention the link from where data is being collected.*
#
# *2. You can collect the data manually. It's NOT a web scraping task.*
#
# *3. Data should be collected for the years mentioned in the files. (If you don't find proper data, make your best judgment and fill it, It's absolutely OK. Do not worry about data accuracy)*

# %% [markdown]
# # Questions:-

# %% [markdown]
# **1. The population of each state.**
#
# **2. Literacy Rate in each state**
#
# **3. Area of each state**
#
# **4. Collect any other data that helps with your analysis. There is no limitation for anything.**
#
# **5. Create a new file and keep the above-collected data.**

# %% [markdown]
# # Answers:-

# %% [markdown]
# # 1. Trying to collect the population of each state.

# %% [markdown]
# **While trying to collect the population data I face a problem like here we can get only 2001 and 2011's population data.So I will scrap these data then I will check the population growth for each state and I will fill the rest of the year's data according to that.I will mention from where I got the 2001 and 2011 population data and from where I got the growth rate in below.Please check those:**

# %% [markdown]
# **For population I took the data from below link:**

# %% [markdown]
# https://m.rbi.org.in/Scripts/PublicationsView.aspx?id=22065

# %% [markdown]
# **For growth rate I took the data from below link:**

# %% [markdown]
# https://m.rbi.org.in/Scripts/PublicationsView.aspx?id=16988

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
#Will open crome
driver=webdriver.Chrome()
#Will access the link on that crome tab
driver.get("https://m.rbi.org.in/Scripts/PublicationsView.aspx?id=22065")

# %%
everything=[]

all_data=driver.find_elements(By.XPATH,'//td')
for i in all_data:
    all_text=i.text
    everything.append(all_text)
    if len(everything)==301:
        break

# %%
raw_data=pd.DataFrame({"States/Union Territories":everything[13::8],"2001":everything[19::8],"2011":everything[20::8]})
raw_data
# Out:
#      States/Union Territories     2001     2011
# 0   Andaman & Nicobar Islands      356      381
# 1              Andhra Pradesh    76210    84581
# 2           Arunachal Pradesh     1098     1384
# 3                       Assam    26656    31206
# 4                       Bihar    82999   104099
# 5                  Chandigarh      901     1055
# 6                Chhattisgarh    20834    25545
# 7        Dadra & Nagar Haveli      220      344
# 8                 Daman & Diu      158      243
# 9                       Delhi    13851    16788
# 10                        Goa     1348     1459
# 11                    Gujarat    50671    60440
# 12                    Haryana    21145    25351
# 13           Himachal Pradesh     6078     6865
# 14            Jammu & Kashmir    10144    12541
# 15                  Jharkhand    26946    32988
# 16                  Karnataka    52851    61095
# 17                     Kerala    31841    33406
# 18                Lakshadweep       61       64
# ...

# %% [markdown]
# # Scraping the growth rate for each state

# %%
#Will open crome
driver=webdriver.Chrome()
#Will access the link on that crome tab
driver.get("https://m.rbi.org.in/Scripts/PublicationsView.aspx?id=16988")

# %%
GR=[]
growth_rate=driver.find_elements(By.XPATH,'//td')
for i in growth_rate:
    growth=i.text
    GR.append(growth)

# %%
GR[18::7]
# Out:
# ['6.68',
#  '11.10',
#  '25.92',
#  '16.93',
#  '25.07',
#  '17.10',
#  '22.59',
#  '55.50',
#  '53.54',
#  '20.96',
#  '8.17',
#  '19.17',
#  '19.90',
#  '12.81',
#  '23.71',
#  '22.34',
#  '15.67',
#  '4.86',
#  '6.23',
#  '20.30',
#  '15.99',
#  '18.65',
#  '27.82',
#  '22.78',
#  '-0.47',
#  '13.97',
#  '27.72',
#  '13.73',
#  '21.44',
#  '12.36',
#  '15.60',
#  '14.75',
#  '20.09',
#  '19.17',
#  '13.93',
#  '17.64']

# %%
raw_data=pd.DataFrame({"States/Union Territories":everything[13::8],"Growth Rate(2001-2011)":GR[18::7],"2001":everything[19::8],"2011":everything[20::8]})
raw_data
# Out:
#      States/Union Territories Growth Rate(2001-2011)     2001     2011
# 0   Andaman & Nicobar Islands                   6.68      356      381
# 1              Andhra Pradesh                  11.10    76210    84581
# 2           Arunachal Pradesh                  25.92     1098     1384
# 3                       Assam                  16.93    26656    31206
# 4                       Bihar                  25.07    82999   104099
# 5                  Chandigarh                  17.10      901     1055
# 6                Chhattisgarh                  22.59    20834    25545
# 7        Dadra & Nagar Haveli                  55.50      220      344
# 8                 Daman & Diu                  53.54      158      243
# 9                       Delhi                  20.96    13851    16788
# 10                        Goa                   8.17     1348     1459
# 11                    Gujarat                  19.17    50671    60440
# ...

# %% [markdown]
# **So now I am going to create 2002 to 2010 population data based on the growth rate and I will use a formula to increase the population.**

# %%
estimated_population_list = []

for index, state_data in raw_data.iterrows():
    growth_rate = float(state_data["Growth Rate(2001-2011)"])
    initial_population_2001 = float(state_data["2001"])  # Convert to numeric type

    # Calculating the annual growth 
    annual_growth = 1 + (growth_rate / 100) / 9

    
    estimated_population = {"States/Union Territories": state_data["States/Union Territories"]}
    for year in range(2002, 2011):
        estimated_population[str(year)] = round(initial_population_2001 * (annual_growth ** (year - 2001)))

    
    estimated_population_list.append(estimated_population)


estimated_population_df = pd.DataFrame(estimated_population_list)


estimated_population_df
# Out:
#      States/Union Territories     2002     2003     2004     2005     2006  \
# 0   Andaman & Nicobar Islands      359      361      364      367      369
# 1              Andhra Pradesh    77150    78101    79065    80040    81027
# 2           Arunachal Pradesh     1130     1162     1196     1230     1265
# 3                       Assam    27157    27668    28189    28719    29259
# 4                       Bihar    85311    87687    90130    92641    95221
# 5                  Chandigarh      918      936      953      971      990
# 6                Chhattisgarh    21357    21893    22443    23006    23583
# 7        Dadra & Nagar Haveli      234      248      263      279      297
# 8                 Daman & Diu      167      177      188      199      211
# 9                       Delhi    14174    14504    14841    15187    15541
# 10                        Goa     1360     1373     1385     1398     1410
# ...

# %%
new_population=pd.merge(raw_data,estimated_population_df,on="States/Union Territories")
new_population
# Out:
#      States/Union Territories Growth Rate(2001-2011)     2001     2011  \
# 0   Andaman & Nicobar Islands                   6.68      356      381
# 1              Andhra Pradesh                  11.10    76210    84581
# 2           Arunachal Pradesh                  25.92     1098     1384
# 3                       Assam                  16.93    26656    31206
# 4                       Bihar                  25.07    82999   104099
# 5                  Chandigarh                  17.10      901     1055
# 6                Chhattisgarh                  22.59    20834    25545
# 7        Dadra & Nagar Haveli                  55.50      220      344
# 8                 Daman & Diu                  53.54      158      243
# 9                       Delhi                  20.96    13851    16788
# 10                        Goa                   8.17     1348     1459
# 11                    Gujarat                  19.17    50671    60440
# ...

# %%
#Changing the 2011 columns location and set it to the last
new_population= new_population[['States/Union Territories', 'Growth Rate(2001-2011)', '2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011'] ]
new_population
# Out:
#      States/Union Territories Growth Rate(2001-2011)     2001     2002  \
# 0   Andaman & Nicobar Islands                   6.68      356      359
# 1              Andhra Pradesh                  11.10    76210    77150
# 2           Arunachal Pradesh                  25.92     1098     1130
# 3                       Assam                  16.93    26656    27157
# 4                       Bihar                  25.07    82999    85311
# 5                  Chandigarh                  17.10      901      918
# 6                Chhattisgarh                  22.59    20834    21357
# 7        Dadra & Nagar Haveli                  55.50      220      234
# 8                 Daman & Diu                  53.54      158      167
# 9                       Delhi                  20.96    13851    14174
# 10                        Goa                   8.17     1348     1360
# 11                    Gujarat                  19.17    50671    51750
# ...

# %% [markdown]
# **Observation:-**
#
# *Here you can see 2011 data is correct because I scrap it from the RBI site but if you look closely here you can see for 2010 population it's higher that the 2011 and that should not be possible so I will reduce the population of 2010 for 1.5%.Lets see:*

# %%
#Decreasing the 2010 columns values by 1.5 %
new_population['2010'] = round(new_population['2010'] * (1 - 1.50 / 100))

# %%
new_population
# Out:
#      States/Union Territories Growth Rate(2001-2011)     2001     2002  \
# 0   Andaman & Nicobar Islands                   6.68      356      359
# 1              Andhra Pradesh                  11.10    76210    77150
# 2           Arunachal Pradesh                  25.92     1098     1130
# 3                       Assam                  16.93    26656    27157
# 4                       Bihar                  25.07    82999    85311
# 5                  Chandigarh                  17.10      901      918
# 6                Chhattisgarh                  22.59    20834    21357
# 7        Dadra & Nagar Haveli                  55.50      220      234
# 8                 Daman & Diu                  53.54      158      167
# 9                       Delhi                  20.96    13851    14174
# 10                        Goa                   8.17     1348     1360
# 11                    Gujarat                  19.17    50671    51750
# ...

# %%
#Removing the decimal part of the 2010 columns data
new_population['2010']=new_population['2010'].astype(int)

# %%
new_population
# Out:
#      States/Union Territories Growth Rate(2001-2011)     2001     2002  \
# 0   Andaman & Nicobar Islands                   6.68      356      359
# 1              Andhra Pradesh                  11.10    76210    77150
# 2           Arunachal Pradesh                  25.92     1098     1130
# 3                       Assam                  16.93    26656    27157
# 4                       Bihar                  25.07    82999    85311
# 5                  Chandigarh                  17.10      901      918
# 6                Chhattisgarh                  22.59    20834    21357
# 7        Dadra & Nagar Haveli                  55.50      220      234
# 8                 Daman & Diu                  53.54      158      167
# 9                       Delhi                  20.96    13851    14174
# 10                        Goa                   8.17     1348     1360
# 11                    Gujarat                  19.17    50671    51750
# ...

# %% [markdown]
# **Here you can see decimal part has been removed for the 2010 column.**

# %% [markdown]
# **Now I will add 2012 column and for that I will increase 2011 columns values to 1.7% because from 2001 to 2011 growth rate was 17.64 and if I divide it with 10 then the result is each year 1.764.Thats why I will take 1.7.**

# %%
#Changing the datatype of 2011 column first
new_population['2011']=pd.to_numeric(new_population['2011'])

# %%
#Adding 2012 column and data in it should be the 2011's data with 1.7% increament
new_population['2012']=round(new_population['2011'] * (1+1.7/100)).astype(int)

# %%
new_population
# Out:
#      States/Union Territories Growth Rate(2001-2011)     2001     2002  \
# 0   Andaman & Nicobar Islands                   6.68      356      359
# 1              Andhra Pradesh                  11.10    76210    77150
# 2           Arunachal Pradesh                  25.92     1098     1130
# 3                       Assam                  16.93    26656    27157
# 4                       Bihar                  25.07    82999    85311
# 5                  Chandigarh                  17.10      901      918
# 6                Chhattisgarh                  22.59    20834    21357
# 7        Dadra & Nagar Haveli                  55.50      220      234
# 8                 Daman & Diu                  53.54      158      167
# 9                       Delhi                  20.96    13851    14174
# 10                        Goa                   8.17     1348     1360
# 11                    Gujarat                  19.17    50671    51750
# ...

# %% [markdown]
# **So here I don't need the Growth Rate(2001-2011) column so I am deleting this column.**

# %%
new_population.drop("Growth Rate(2001-2011)",axis=1,inplace=True)
new_population
# Out:
#      States/Union Territories     2001     2002     2003     2004     2005  \
# 0   Andaman & Nicobar Islands      356      359      361      364      367
# 1              Andhra Pradesh    76210    77150    78101    79065    80040
# 2           Arunachal Pradesh     1098     1130     1162     1196     1230
# 3                       Assam    26656    27157    27668    28189    28719
# 4                       Bihar    82999    85311    87687    90130    92641
# 5                  Chandigarh      901      918      936      953      971
# 6                Chhattisgarh    20834    21357    21893    22443    23006
# 7        Dadra & Nagar Haveli      220      234      248      263      279
# 8                 Daman & Diu      158      167      177      188      199
# 9                       Delhi    13851    14174    14504    14841    15187
# 10                        Goa     1348     1360     1373     1385     1398
# ...

# %% [markdown]
# **Now you can see Growth Rate(2001-2011) column is deleted.**

# %%
#Replaceing Jammu & Kashmir name with Jammu and Kashmir so I can merge easily in the later part
new_population["States/Union Territories"].replace("Jammu & Kashmir","Jammu and Kashmir",inplace=True)

# %% [markdown]
# # Creating another shape of Population dataset

# %%
#Reshaping the dataset according the file I got
population_df = new_population.melt(id_vars=['States/Union Territories'], var_name='Year', value_name='Population')

# Converting the 'Year' column to numeric
population_df['Year'] = population_df['Year'].astype(int)

# Sort the DataFrame for better presentation
population_df.sort_values(['States/Union Territories', 'Year'], inplace=True)


population_df
# Out:
#     States/Union Territories  Year Population
# 35                 ALL INDIA  2001    1028737
# 71                 ALL INDIA  2002    1048900
# 107                ALL INDIA  2003    1069459
# 143                ALL INDIA  2004    1090420
# 179                ALL INDIA  2005    1111792
# ..                       ...   ...        ...
# 286              West Bengal  2008      89277
# 322              West Bengal  2009      90658
# 358              West Bengal  2010      90681
# 394              West Bengal  2011      91276
# 430              West Bengal  2012      92828
#
# [432 rows x 3 columns]

# %%
population_df["States/Union Territories"].unique().tolist()
# Out:
# ['ALL INDIA',
#  'Andaman & Nicobar Islands',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal']

# %% [markdown]
# # 2. Scraping the literacy Rate in each state

# %% [markdown]
# **For the each state literacy rate I took the data from below link:**

# %% [markdown]
# https://www.rbi.org.in/scripts/PublicationsView.aspx?id=19995

# %%
#Will open crome
driver=webdriver.Chrome()
#Will access the link on that crome tab
driver.get("https://www.rbi.org.in/scripts/PublicationsView.aspx?id=19995")

# %%
literacy=[]

lit_data=driver.find_elements(By.XPATH,'//td')
for i in lit_data:
    lit_text=i.text
    literacy.append(lit_text)
    if len(literacy)==301:
        break

# %%
Literacy=pd.DataFrame({"States/Union Territories":literacy[13::8],"2001":literacy[19::8],"2011":literacy[20::8]})
Literacy
# Out:
#        States/Union Territories   2001   2011
# 0   Andaman and Nicobar Islands  81.30  86.63
# 1                Andhra Pradesh  60.47  67.02
# 2             Arunachal Pradesh  54.34  65.39
# 3                         Assam  63.25  72.19
# 4                         Bihar  47.00  61.80
# 5                    Chandigarh  81.94  86.05
# 6                  Chhattisgarh  64.66  70.28
# 7        Dadra and Nagar Haveli  57.63  76.24
# 8                 Daman and Diu  78.18  87.10
# 9                         Delhi  81.67  86.21
# 10                          Goa  82.01  88.70
# 11                      Gujarat  69.14  78.03
# 12                      Haryana  67.91  75.55
# 13             Himachal Pradesh  76.48  82.80
# 14            Jammu and Kashmir  55.52  67.16
# 15                    Jharkhand  53.56  66.41
# 16                    Karnataka  66.60  75.37
# 17                       Kerala  90.86  94.00
# 18                  Lakshadweep  86.66  91.85
# ...

# %% [markdown]
# **Observation:-**
#
# *1) Here you can see the literacy rate of only 2001 and 2011 but I have the data of 2001 to 2012 so for rest of the columns I have to fill that.*
#
# *2) From 2001 to 2011 ,in between there are 9 years and in 2001 the literacy rate of of India is 64.84 and of 2011 that is 72.99 meas it increases like 8.15% in these 9 years that means 0.90% increament each year so I will create the 2002 to 2010 and 2012 literacy rate data by increamenting the values for each year.*

# %%
#Changing the datatype of 2001 column first
Literacy['2001']=pd.to_numeric(Literacy['2001'])

# %%
#Adding 2002 column and data in it should be the 2001's data with 0.37% increament
Literacy['2002']=round(Literacy['2001'] * (1+0.37/100),2).astype(float)

# %%
#Now I will create different columns of year with incremented literacy rate
Literacy['2003']=round(Literacy['2002'] * (1+0.45/100),2).astype(float)
Literacy['2004']=round(Literacy['2003'] * (1+0.37/100),2).astype(float)
Literacy['2005']=round(Literacy['2004'] * (1+0.33/100),2).astype(float)
Literacy['2006']=round(Literacy['2005'] * (1+0.26/100),2).astype(float)
Literacy['2007']=round(Literacy['2006'] * (1+0.52/100),2).astype(float)

# %%
#Adding more columns
Literacy['2008']=round(Literacy['2007'] * (1+0.59/100),2).astype(float)
Literacy['2009']=round(Literacy['2008'] * (1+1.00/100),2).astype(float)
Literacy['2010']=round(Literacy['2009'] * (1+0.56/100),2).astype(float)
#Checging the datatype of Literacy['Literacy Rate of 2011'] column
Literacy['2011']=pd.to_numeric(Literacy['2011'])
Literacy['2012']=round(Literacy['2011'] * (1+0.45/100),2).astype(float)

# %%
#setting the column in ascending order
Literacy=Literacy[["States/Union Territories","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012"]]
Literacy
# Out:
#        States/Union Territories   2001   2002   2003   2004   2005   2006  \
# 0   Andaman and Nicobar Islands  81.30  81.60  81.97  82.27  82.54  82.75
# 1                Andhra Pradesh  60.47  60.69  60.96  61.19  61.39  61.55
# 2             Arunachal Pradesh  54.34  54.54  54.79  54.99  55.17  55.31
# 3                         Assam  63.25  63.48  63.77  64.01  64.22  64.39
# 4                         Bihar  47.00  47.17  47.38  47.56  47.72  47.84
# 5                    Chandigarh  81.94  82.24  82.61  82.92  83.19  83.41
# 6                  Chhattisgarh  64.66  64.90  65.19  65.43  65.65  65.82
# 7        Dadra and Nagar Haveli  57.63  57.84  58.10  58.31  58.50  58.65
# 8                 Daman and Diu  78.18  78.47  78.82  79.11  79.37  79.58
# 9                         Delhi  81.67  81.97  82.34  82.64  82.91  83.13
# 10                          Goa  82.01  82.31  82.68  82.99  83.26  83.48
# 11                      Gujarat  69.14  69.40  69.71  69.97  70.20  70.38
# ...

# %% [markdown]
# **Observation:-**
#
# 1) Now you can see my literacy dataset is ready and it has 2001 to 2012 data in it.

# %% [markdown]
# # Creating another shape of Literacy dataset

# %%
#Reshaping the dataset according the file I got
Literacy_df = Literacy.melt(id_vars=['States/Union Territories'], var_name='Year', value_name='Literacy Rate')

# Converting the 'Year' column to numeric
Literacy_df['Year'] = Literacy_df['Year'].astype(int)

# Sort the DataFrame for better presentation
Literacy_df.sort_values(['States/Union Territories', 'Year'], inplace=True)


Literacy_df
# Out:
#     States/Union Territories  Year  Literacy Rate
# 35                 ALL INDIA  2001          64.84
# 71                 ALL INDIA  2002          65.08
# 107                ALL INDIA  2003          65.37
# 143                ALL INDIA  2004          65.61
# 179                ALL INDIA  2005          65.83
# ..                       ...   ...            ...
# 286              West Bengal  2008          70.64
# 322              West Bengal  2009          71.35
# 358              West Bengal  2010          71.75
# 394              West Bengal  2011          76.26
# 430              West Bengal  2012          76.60
#
# [432 rows x 3 columns]

# %%
#Replacing some values so I can easily marge in later part
Literacy_df["States/Union Territories"].replace("Andaman and Nicobar Islands","Andaman & Nicobar Islands",inplace=True)

# %%
Literacy_df["States/Union Territories"].replace("Dadra and Nagar Haveli","Dadra & Nagar Haveli",inplace=True)
Literacy_df["States/Union Territories"].replace("Daman and Diu","Daman & Diu",inplace=True)

# %%
Literacy_df["States/Union Territories"].unique().tolist()
# Out:
# ['ALL INDIA',
#  'Andaman & Nicobar Islands',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal']

# %% [markdown]
# # 3. Scraping the area of each state

# %% [markdown]
# **For area of each state I took the data from below link:**

# %% [markdown]
# https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_area

# %%
#Will open crome
driver=webdriver.Chrome()
#Will access the link on that crome tab
driver.get("https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_area")
time.sleep(3)

# %%
click=driver.find_element(By.XPATH,'//th[@class="headerSort"][2]')
click.click()
time.sleep(3)
area=[]

all_data=driver.find_elements(By.XPATH,'//td')
for i in all_data:
    all_text=i.text
    area.append(all_text)

# %%
area
# Out:
# ['',
#  'Area Population GDP (per capita)\nAbbreviations Access to safe drinking water Availability of toilets Capitals Child nutrition Crime rate Ease of doing business Electricity penetration Exports Fertility rate Forest cover Highest point HDI Home ownership Household size Human trafficking Institutional delivery Life expectancy at birth Literacy rate Media exposure Number of vehicles Number of voters Open defecation Origin of name Past population Places of worship Poverty rate Power capacity Safety of women School enrollment rate Sex ratio Suicide rate Tax revenues TV ownership Transport network Underweight people Unemployment rate Vaccination coverage Wildlife population',
#  'vte',
#  '29 (UT3)',
#  'Andaman and Nicobar Islands',
#  '8,249',
#  'Bay of Bengal',
#  '0.251',
#  '',
#  '7 (S7)',
#  'Andhra Pradesh',
#  '162,975',
#  'Southern',
#  '4.957',
#  '[b]',
#  '14 (S14)',
#  'Arunachal Pradesh',
#  '83,743',
#  'Northeastern',
#  '2.548',
#  '',
#  '16 (S16)',
# ...

# %%
#Editing the list for necessary changes
a=['',
 'Area Population GDP (per capita)\nAbbreviations Access to safe drinking water Availability of toilets Capitals Child nutrition Crime rate Ease of doing business Electricity penetration Exports Fertility rate Forest cover Highest point HDI Home ownership Household size Human trafficking Institutional delivery Life expectancy at birth Literacy rate Media exposure Number of vehicles Number of voters Open defecation Origin of name Past population Places of worship Poverty rate Power capacity Safety of women School enrollment rate Sex ratio Suicide rate Tax revenues TV ownership Transport network Underweight people Unemployment rate Vaccination coverage Wildlife population',
 'vte',
 '29 (UT3)',
 'Andaman & Nicobar Islands',
 '8,249',
 'Bay of Bengal',
 '0.251',
 '',
 '7 (S7)',
 'Andhra Pradesh',
 '162,975',
 'Southern',
 '4.957',
 '[b]',
 '14 (S14)',
 'Arunachal Pradesh',
 '83,743',
 'Northeastern',
 '2.548',
 '',
 '16 (S16)',
 'Assam',
 '78,438',
 'Northeastern',
 '2.386',
 '',
 '12 (S12)',
 'Bihar',
 '94,163',
 'Eastern',
 '2.864',
 '',
 '35 (UT7)',
 'Chandigarh',
 '114',
 'Northern',
 '0.003',
 '',
 '9 (S9)',
 'Chhattisgarh',
 '135,192',
 'Central',
 '4.112',
 '[c]',
 '33 (UT5)',
 'Dadra & Nagar Haveli',
 '491',
 'Western',
 '0.018',
 '[5]',
  '33 (UT5)',
 'Daman & Diu',
 '112',
 'Western',
 '0.018',
 '[5]', 
 '32 (UT4)',
 'Delhi',
 '1,484',
 'Northern',
 '0.045',
 '',
 '31 (S28)',
 'Goa',
 '3,702',
 'Western',
 '0.112',
 '',
 '5 (S5)',
 'Gujarat',
 '196,024',
 'Western',
 '5.962',
 '',
 '21(S20)',
 'Haryana',
 '44,212',
 'Northern',
 '1.344',
 '',
 '18 (S17)',
 'Himachal Pradesh',
 '55,673',
 'Northern',
 '1.693',
 '',
 '22 (UT2)',
 'Jammu and Kashmir',
 '42,241\n(55,538)',
 'Northern',
 '1.285\n(1.689)',
 '[e]',
 '15 (S15)',
 'Jharkhand',
 '79,716',
 'Eastern',
 '2.424',
 '',
 '6 (S6)',
 'Karnataka',
 '191,791',
 'Southern',
 '5.833',
 '',
 '23 (S21)',
 'Kerala',
 '38,863',
 'Southern',
 '1.182',
 '',
 '36 (UT8)',
 'Lakshadweep',
 '32',
 'Arabian Sea',
 '0.001',
 '',
 '2 (S2)',
 'Madhya Pradesh',
 '308,252',
 'Central',
 '9.376',
 '[a]',
 '3 (S3)',
 'Maharashtra',
 '307,713',
 'Western',
 '9.359',
 '',
 '25 (S23)',
 'Manipur',
 '22,327',
 'Northeastern',
 '0.680',
 '',
 '24 (S22)',
 'Meghalaya',
 '22,429',
 'Northeastern',
 '0.682',
 '',
 '26 (S24)',
 'Mizoram',
 '21,081',
 'Northeastern',
 '0.642',
 '',
 '27 (S25)',
 'Nagaland',
 '16,579',
 'Northeastern',
 '0.505',
 '',
 '8 (S8)',
 'Odisha',
 '155,707',
 'Eastern',
 '4.736',
 '',
 '34 (UT6)',
 'Puducherry',
 '479',
 'Southern',
 '0.015',
 '[f]',
 '20 (S19)',
 'Punjab',
 '50,362',
 'Northern',
 '1.531',
 '',
 '1 (S1)',
 'Rajasthan',
 '342,239',
 'Western',
 '10.414',
 '',
 '30 (S27)',
 'Sikkim',
 '7,096',
 'Northeastern',
 '0.217',
 '',
 '10 (S10)',
 'Tamil Nadu',
 '130,058',
 'Southern',
 '3.956',
 '',
 '28 (S26)',
 'Tripura',
 '10,491',
 'Northeastern',
 '0.320',
 '',
 '4 (S4)',
 'Uttar Pradesh',
 '240,928',
 'Northern',
 '7.328',
 '',
 '19 (S18)',
 'Uttarakhand',
 '53,483',
 'Northern',
 '1.626',
 '',
 '13 (S13)',
 'West Bengal',
 '88,752',
 'Eastern',
 '2.700',
 '',
  '',
 'India',
 '3,287,263\n(3,166,414)[g]',
 '',
 '100\n(96.323)',
 '',]

# %% [markdown]
# **Here I place the India data in the bottom of the list to match with other Dataset.Because in other dataset whole India value is present in the bottom row of the dataset.**

# %%
area=pd.DataFrame({"States/Union Territories":everything[13::8],"Area (Km2)":a[5::6]})
area
# Out:
#      States/Union Territories                 Area (Km2)
# 0   Andaman & Nicobar Islands                      8,249
# 1              Andhra Pradesh                    162,975
# 2           Arunachal Pradesh                     83,743
# 3                       Assam                     78,438
# 4                       Bihar                     94,163
# 5                  Chandigarh                        114
# 6                Chhattisgarh                    135,192
# 7        Dadra & Nagar Haveli                        491
# 8                 Daman & Diu                        112
# 9                       Delhi                      1,484
# 10                        Goa                      3,702
# 11                    Gujarat                    196,024
# 12                    Haryana                     44,212
# 13           Himachal Pradesh                     55,673
# 14            Jammu & Kashmir           42,241\n(55,538)
# ...

# %%
#Replaceing Jammu & Kashmir name with Jammu and Kashmir so I can merge easily in the later part
area["States/Union Territories"].replace("Jammu & Kashmir","Jammu and Kashmir",inplace=True)

# %%
area["States/Union Territories"].unique().tolist()
# Out:
# ['Andaman & Nicobar Islands',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal',
#  'ALL INDIA']

# %% [markdown]
# # 4.Collect any other data that helps with your analysis. There is no limitation for anything.

# %% [markdown]
# **I will take Proverty rate and for that I will create collecct the data manually and I am mentioned the link from where I get this data below:**

# %% [markdown]
# https://www.rbi.org.in/scripts/PublicationsView.aspx?id=18810

# %%
Proverty={"States/Union Territories":area["States/Union Territories"].to_list(),"2011-12 (Based on MRP Consumption)":[1.00,9.20,34.67,31.98,33.74,21.81,39.93,39.31,9.86,9.91,5.09,16.63,11.16,8.06,10.35,36.96,20.91,7.05,2.77,31.65,17.35,36.89,11.87,20.40,11.88,32.59,9.69,8.26,14.71,8.119,11.28,14.05,29.43,11.26,19.98,21.92]}

# %%
Proverty_df=pd.DataFrame(Proverty)
Proverty_df
# Out:
#      States/Union Territories  2011-12 (Based on MRP Consumption)
# 0   Andaman & Nicobar Islands                               1.000
# 1              Andhra Pradesh                               9.200
# 2           Arunachal Pradesh                              34.670
# 3                       Assam                              31.980
# 4                       Bihar                              33.740
# 5                  Chandigarh                              21.810
# 6                Chhattisgarh                              39.930
# 7        Dadra & Nagar Haveli                              39.310
# 8                 Daman & Diu                               9.860
# 9                       Delhi                               9.910
# 10                        Goa                               5.090
# 11                    Gujarat                              16.630
# 12                    Haryana                              11.160
# ...

# %%
#Replaceing Jammu & Kashmir name with Jammu and Kashmir so I can merge easily in the later part
Proverty_df["States/Union Territories"].replace("Jammu & Kashmir","Jammu and Kashmir",inplace=True)

# %%
Proverty_df["States/Union Territories"].unique().tolist()
# Out:
# ['Andaman & Nicobar Islands',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal',
#  'ALL INDIA']

# %% [markdown]
# # 5. Create a new file and keep the above-collected data.

# %%
Marge_Population_Literacy_Area_Proverty = population_df.merge(Literacy_df, on=['States/Union Territories', 'Year']).merge(area,on='States/Union Territories').merge(Proverty_df,on='States/Union Territories')
Marge_Population_Literacy_Area_Proverty
# Out:
#     States/Union Territories  Year Population  Literacy Rate  \
# 0                  ALL INDIA  2001    1028737          64.84
# 1                  ALL INDIA  2002    1048900          65.08
# 2                  ALL INDIA  2003    1069459          65.37
# 3                  ALL INDIA  2004    1090420          65.61
# 4                  ALL INDIA  2005    1111792          65.83
# ..                       ...   ...        ...            ...
# 427              West Bengal  2008      89277          70.64
# 428              West Bengal  2009      90658          71.35
# 429              West Bengal  2010      90681          71.75
# 430              West Bengal  2011      91276          76.26
# 431              West Bengal  2012      92828          76.60
#
#                     Area (Km2)  2011-12 (Based on MRP Consumption)
# 0    3,287,263\n(3,166,414)[g]                               21.92
# 1    3,287,263\n(3,166,414)[g]                               21.92
# ...

# %%
#Createing a dictionary for replacing value
replace={'ALL INDIA':'ALL INDIA',
 'Andaman & Nicobar Islands':'A & N ISLANDS',
 'Andhra Pradesh':'ANDHRA PRADESH',
 'Arunachal Pradesh':'ARUNACHAL PRADESH',
 'Assam':'ASSAM',
 'Bihar':'BIHAR',
 'Chandigarh':'CHANDIGARH',
 'Chhattisgarh':'CHHATTISGARH',
 'Dadra & Nagar Haveli':'D & N HAVELI',
 'Daman & Diu':'DAMAN & DIU',
 'Delhi':'DELHI',
 'Goa':'GOA',
 'Gujarat':'GUJARAT',
 'Haryana':'HARYANA',
 'Himachal Pradesh':'HIMACHAL PRADESH',
 'Jammu and Kashmir':'JAMMU & KASHMIR',
 'Jharkhand':'JHARKHAND',
 'Karnataka':'KARNATAKA',
 'Kerala':'KERALA',
 'Lakshadweep':'LAKSHADWEEP',
 'Madhya Pradesh':'MADHYA PRADESH',
 'Maharashtra':'MAHARASHTRA',
 'Manipur':'MANIPUR',
 'Meghalaya':'MEGHALAYA',
 'Mizoram':'MIZORAM',
 'Nagaland':'NAGALAND',
 'Odisha':'ODISHA',
 'Puducherry':'PUDUCHERRY',
 'Punjab':'PUNJAB',
 'Rajasthan':'RAJASTHAN',
 'Sikkim':'SIKKIM',
 'Tamil Nadu':'TAMIL NADU',
 'Tripura':'TRIPURA',
 'Uttar Pradesh':'UTTAR PRADESH',
 'Uttarakhand':'UTTARAKHAND',
 'West Bengal':'WEST BENGAL'
    
}

# %%
#Changing the state values according to the given files state values so I can easyly marge it for later part
Marge_Population_Literacy_Area_Proverty["States/Union Territories"].replace(replace,inplace=True)
Marge_Population_Literacy_Area_Proverty
# Out:
#     States/Union Territories  Year Population  Literacy Rate  \
# 0                  ALL INDIA  2001    1028737          64.84
# 1                  ALL INDIA  2002    1048900          65.08
# 2                  ALL INDIA  2003    1069459          65.37
# 3                  ALL INDIA  2004    1090420          65.61
# 4                  ALL INDIA  2005    1111792          65.83
# ..                       ...   ...        ...            ...
# 427              WEST BENGAL  2008      89277          70.64
# 428              WEST BENGAL  2009      90658          71.35
# 429              WEST BENGAL  2010      90681          71.75
# 430              WEST BENGAL  2011      91276          76.26
# 431              WEST BENGAL  2012      92828          76.60
#
#                     Area (Km2)  2011-12 (Based on MRP Consumption)
# 0    3,287,263\n(3,166,414)[g]                               21.92
# 1    3,287,263\n(3,166,414)[g]                               21.92
# ...

# %%
#Changing the State columns names according to files given by you
Marge_Population_Literacy_Area_Proverty.rename(columns={'States/Union Territories': 'STATE/UT'}, inplace=True)

# %%
Marge_Population_Literacy_Area_Proverty
# Out:
#         STATE/UT  Year Population  Literacy Rate                 Area (Km2)  \
# 0      ALL INDIA  2001    1028737          64.84  3,287,263\n(3,166,414)[g]
# 1      ALL INDIA  2002    1048900          65.08  3,287,263\n(3,166,414)[g]
# 2      ALL INDIA  2003    1069459          65.37  3,287,263\n(3,166,414)[g]
# 3      ALL INDIA  2004    1090420          65.61  3,287,263\n(3,166,414)[g]
# 4      ALL INDIA  2005    1111792          65.83  3,287,263\n(3,166,414)[g]
# ..           ...   ...        ...            ...                        ...
# 427  WEST BENGAL  2008      89277          70.64                     88,752
# 428  WEST BENGAL  2009      90658          71.35                     88,752
# 429  WEST BENGAL  2010      90681          71.75                     88,752
# 430  WEST BENGAL  2011      91276          76.26                     88,752
# 431  WEST BENGAL  2012      92828          76.60                     88,752
#
#      2011-12 (Based on MRP Consumption)
# ...

# %%
#Changing the Year column with YEAR
Marge_Population_Literacy_Area_Proverty.rename(columns={'Year': 'YEAR'}, inplace=True)

Marge_Population_Literacy_Area_Proverty
# Out:
#         STATE/UT  YEAR Population  Literacy Rate                 Area (Km2)  \
# 0      ALL INDIA  2001    1028737          64.84  3,287,263\n(3,166,414)[g]
# 1      ALL INDIA  2002    1048900          65.08  3,287,263\n(3,166,414)[g]
# 2      ALL INDIA  2003    1069459          65.37  3,287,263\n(3,166,414)[g]
# 3      ALL INDIA  2004    1090420          65.61  3,287,263\n(3,166,414)[g]
# 4      ALL INDIA  2005    1111792          65.83  3,287,263\n(3,166,414)[g]
# ..           ...   ...        ...            ...                        ...
# 427  WEST BENGAL  2008      89277          70.64                     88,752
# 428  WEST BENGAL  2009      90658          71.35                     88,752
# 429  WEST BENGAL  2010      90681          71.75                     88,752
# 430  WEST BENGAL  2011      91276          76.26                     88,752
# 431  WEST BENGAL  2012      92828          76.60                     88,752
#
#      2011-12 (Based on MRP Consumption)
# ...

# %% [markdown]
# # Exporting the file

# %%
Marge_Population_Literacy_Area_Proverty.to_csv("Combine.csv",index=False)
